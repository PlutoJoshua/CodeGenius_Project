# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -------------
# absl-py                      2.1.0
# accelerate                   0.30.1
# aiohttp                      3.9.5
# aiosignal                    1.3.1
# annotated-types              0.7.0
# asgiref                      3.8.1
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-timeout                4.0.3
# attrs                        23.2.0
# beautifulsoup4               4.12.3
# beniget                      0.4.1
# blinker                      1.4
# boto3                        1.34.113
# botocore                     1.34.113
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# click                        8.1.7
# comm                         0.2.2
# command-not-found            0.3
# contourpy                    1.2.1
# cryptography                 3.4.8
# cycler                       0.12.1
# ...
