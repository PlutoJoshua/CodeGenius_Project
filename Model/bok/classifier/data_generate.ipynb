# %% [markdown]
# # api classifier

# %%
# !pip install google-cloud-ai-generation

# %%
import google.generativeai as genai

api_key = "AIzaSyCLmV2CGmQRyqRlfysRuW1XzOB-2c_Yd44"  # 여기에 자신의 API 키를 넣어주세요

genai.configure(api_key=api_key)
model = genai.GenerativeModel('gemini-pro')

# %%
system_prompt =  """
당신은 user_prompt가 파이썬과 관련된 질문인지 아닌지 분류하는 모델입니다.
user_prompt가 파이썬과 관련된 질문 중에서 "파이썬 정의, 파이썬 기초, 조건문, 반복문, 변수, 내장함수, 기본 패키지, 개행문자, 문자열 포맷, tuple, list, set, 넘파이, 판다스, 배열, 행렬, 시각화, matplotlib, seaborn, plotly, 기초통계, 가설검정, 회귀분석, 상관분석, 차이분석, 그룹화, 탐색적 데이터 분석, 데이터 전처리, 데이터의 종류, 데이터의 특성"과 관련된 질문인지 아닌지 분류해주세요.
해당 키워드와 관련된 질문이면 yes로 답변해주세요.
파이썬과 관련된 질문이지만 해당 키워드와 관련이 없는 질문이라면 no로 답변해주세요.
yes나 no로 분류하기 애매한 질문이라면 check로 답변해주세요.
파이썬과 완전 무관한 질문도 no로 답변해주세요.

답변이 yes인 질문 예시: 문자열의 소문자를 대문자로 변환하는 방법
답변이 no인 질문 예시: 문자열의 소문자를 방법
답변이 check인 질문 예시: 문자를 변환하는 방법
"""

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -------------
# absl-py                      2.1.0
# accelerate                   0.30.1
# aiohttp                      3.9.5
# aiosignal                    1.3.1
# annotated-types              0.7.0
# asgiref                      3.8.1
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-timeout                4.0.3
# attrs                        23.2.0
# beautifulsoup4               4.12.3
# beniget                      0.4.1
# blinker                      1.4
# boto3                        1.34.113
# botocore                     1.34.113
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# click                        8.1.7
# comm                         0.2.2
# command-not-found            0.3
# contourpy                    1.2.1
# cryptography                 3.4.8
# cycler                       0.12.1
# Cython                       3.0.10
# datasets                     2.19.1
# dbus-python                  1.2.18
# debugpy                      1.8.1
# decorator                    5.1.1
# dill                         0.3.8
# distro                       1.7.0
# distro-info                  1.1+ubuntu0.2
# Django                       5.0
# et-xmlfile                   1.1.0
# exceptiongroup               1.2.1
# executing                    2.0.1
# fasttext                     0.9.2
# filelock                     3.14.0
# flatbuffers                  24.3.25
# fonttools                    4.52.4
# frozenlist                   1.4.1
# fsspec                       2024.3.1
# gast                         0.5.4
# gensim                       4.3.2
# gluonnlp                     0.10.0
# google-ai-generativelanguage 0.6.4
# google-api-core              2.19.0
# google-api-python-client     2.131.0
# google-auth                  2.29.0
# google-auth-httplib2         0.2.0
# google-generativeai          0.5.4
# google-pasta                 0.2.0
# googleapis-common-protos     1.63.0
# graphviz                     0.8.4
# grpcio                       1.64.0
# grpcio-status                1.62.2
# h11                          0.14.0
# h5py                         3.11.0
# httplib2                     0.20.2
# huggingface-hub              0.23.1
# idna                         3.7
# importlib-metadata           4.6.4
# ipykernel                    6.29.4
# ipython                      8.24.0
# ipywidgets                   8.1.3
# jedi                         0.19.1
# jeepney                      0.7.1
# jellyfish                    1.0.3
# Jinja2                       3.1.4
# jmespath                     1.0.1
# joblib                       1.4.2
# JPype1                       1.5.0
# jupyter_client               8.6.2
# jupyter_core                 5.7.2
# jupyterlab_widgets           3.0.11
# keras                        3.3.3
# keybert                      0.8.4
# keyring                      23.5.0
# kiwipiepy                    0.17.1
# kiwipiepy-model              0.17.0
# kiwisolver                   1.4.5
# kobert-tokenizer             0.1
# konlpy                       0.6.0
# launchpadlib                 1.10.16
# lazr.restfulclient           0.14.4
# lazr.uri                     1.0.6
# libclang                     18.1.1
# lxml                         5.2.2
# Markdown                     3.6
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.5
# matplotlib                   3.9.0
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# ml-dtypes                    0.3.2
# more-itertools               8.10.0
# mpmath                       1.3.0
# multidict                    6.0.5
# multiprocess                 0.70.16
# mxnet                        1.9.1
# namex                        0.0.8
# nest-asyncio                 1.6.0
# netifaces                    0.11.0
# networkx                     3.3
# nltk                         3.8.1
# numpy                        1.26.4
# nvidia-cublas-cu12           12.1.3.1
# nvidia-cuda-cupti-cu12       12.1.105
# nvidia-cuda-nvrtc-cu12       12.1.105
# nvidia-cuda-runtime-cu12     12.1.105
# nvidia-cudnn-cu12            8.9.2.26
# nvidia-cufft-cu12            11.0.2.54
# nvidia-curand-cu12           10.3.2.106
# nvidia-cusolver-cu12         11.4.5.107
# nvidia-cusparse-cu12         12.1.0.106
# nvidia-nccl-cu12             2.20.5
# nvidia-nvjitlink-cu12        12.5.40
# nvidia-nvtx-cu12             12.1.105
# oauthlib                     3.2.0
# olefile                      0.46
# openpyxl                     3.1.2
# opt-einsum                   3.3.0
# optree                       0.11.0
# outcome                      1.3.0.post0
# packaging                    24.0
# pandas                       2.2.2
# parso                        0.8.4
# pexpect                      4.9.0
# Pillow                       9.0.1
# pip                          22.0.2
# platformdirs                 4.2.2
# ply                          3.11
# prompt-toolkit               3.0.43
# proto-plus                   1.23.0
# protobuf                     4.25.3
# psutil                       5.9.8
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# pyarrow                      16.1.0
# pyarrow-hotfix               0.6
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# pybind11                     2.12.0
# pydantic                     2.7.2
# pydantic_core                2.18.3
# Pygments                     2.18.0
# PyGObject                    3.42.1
# PyJWT                        2.3.0
# pyparsing                    2.4.7
# PySocks                      1.7.1
# python-apt                   2.4.0+ubuntu3
# python-dateutil              2.9.0.post0
# pythran                      0.10.0
# pytz                         2024.1
# PyYAML                       5.4.1
# pyzmq                        26.0.3
# rake-nltk                    1.0.6
# regex                        2024.5.15
# requests                     2.32.2
# rich                         13.7.1
# rsa                          4.9
# s3transfer                   0.10.1
# safetensors                  0.4.3
# scikit-learn                 1.5.0
# scipy                        1.13.1
# SecretStorage                3.3.1
# segtok                       1.5.11
# selenium                     4.21.0
# sentence-transformers        2.7.0
# sentencepiece                0.2.0
# setuptools                   59.6.0
# six                          1.16.0
# smart-open                   7.0.4
# sniffio                      1.3.1
# sortedcontainers             2.4.0
# soupsieve                    2.5
# sqlparse                     0.5.0
# stack-data                   0.6.3
# sympy                        1.12
# systemd-python               234
# tabulate                     0.9.0
# tensorboard                  2.16.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.16.1
# tensorflow-io-gcs-filesystem 0.37.0
# termcolor                    2.4.0
# tf_keras                     2.16.0
# threadpoolctl                3.5.0
# tokenizers                   0.19.1
# torch                        2.3.0
# tornado                      6.4
# tqdm                         4.66.4
# traitlets                    5.14.3
# transformers                 4.41.1
# trio                         0.25.1
# trio-websocket               0.11.1
# triton                       2.3.0
# typing_extensions            4.12.0
# tzdata                       2024.1
# ubuntu-pro-client            8001
# ufw                          0.36.1
# unattended-upgrades          0.1
# uritemplate                  4.1.1
# urllib3                      2.2.1
# wadllib                      1.3.6
# wcwidth                      0.2.13
# Werkzeug                     3.0.3
# wheel                        0.37.1
# widgetsnbextension           4.0.11
# wrapt                        1.16.0
# wsproto                      1.2.0
# xxhash                       3.4.1
# yake                         0.4.8
# yarl                         1.9.4
# zipp                         1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time

# %%
# 질문 설정
user_prompt = input()

# %%
# 답변 생성
start_time = time.time()
result = model.generate_content(system_prompt + user_prompt)
result.text
# print(time.time() - start_time)
# Out:
# 'check'

# %%
result.text
# Out:
# 'no'

# %%
import pandas as pd
x = pd.read_csv('../data/raw_data/rawdata.csv', index_col=0)

# %%
for i in x.question.tolist()[:10]:
    user_prompt = i
    result = model.generate_content(system_prompt + user_prompt)
    print(i, result.text)
# Out:
# 파이썬에서 변수의 데이터 타입을 확인하는 방법은? yes
# 리스트에서 특정 요소를 삭제하는 방법은? yes
# 문자열의 소문자를 대문자로 변환하는 방법은? yes
# 함수에 인수를 전달할 때 키워드 인수를 사용하는 장점은 무엇인가요? yes
# 사전에서 키에 해당하는 값을 검색하는 방법은? yes
# Python에서 숫자를 문자열로 변환하는 방법은? yes
# 반복문을 사용하여 리스트의 모든 요소에 작업을 수행하는 방법은? yes
# 조건문을 사용하여 조건에 따라 다른 코드를 실행하는 방법은? yes
# 함수를 정의하고 사용하는 방법은? yes
# 파이썬에서 변수에 문자열을 지정하는 방법은 무엇인가요? yes

# %%
import google.generativeai as genai

def GOOGLEAI(user_prompt):
    api_key = "AIzaSyCLmV2CGmQRyqRlfysRuW1XzOB-2c_Yd44"  # 여기에 자신의 API 키를 넣어주세요

    genai.configure(api_key=api_key)
    model = genai.GenerativeModel('gemini-pro')

    # 프롬프트 엔지니어링
    system_prompt =  """
    당신은 user_prompt가 파이썬과 관련된 질문인지 아닌지 분류하는 모델입니다.
    user_prompt가 파이썬과 관련된 질문 중에서 "파이썬 정의, 파이썬 기초, 조건문, 반복문, 변수, 내장함수, 기본 패키지, 개행문자, 문자열 포맷, tuple, list, set, 넘파이, 판다스, 배열, 행렬, 시각화, matplotlib, seaborn, plotly, 기초통계, 가설검정, 회귀분석, 상관분석, 차이분석, 그룹화, 탐색적 데이터 분석, 데이터 전처리, 데이터의 종류, 데이터의 특성"과 관련된 질문인지 아닌지 분류해주세요.
    해당 키워드와 관련된 질문이면 yes로 답변해주세요.
    파이썬과 관련된 질문이지만 해당 키워드와 관련이 없는 질문이라면 check로 답변해주세요.
    yes나 no로 분류하기 애매한 질문이라면 check로 답변해주세요.
    파이썬과 완전 무관한 질문은 no로 답변해주세요.

    답변이 yes인 질문 예시: 문자열의 소문자를 대문자로 변환하는 방법
    답변이 no인 질문 예시: 문자열의 소문자를 방법
    답변이 check인 질문 예시: 파이썬에서 RNN이 무엇인가요?
    """
    
    # 답변 생성
    result = model.generate_content(system_prompt + user_prompt)
    output = result.text

    return output

# %%
# 질문 설정
user_prompt = input()

# %%
GOOGLEAI(user_prompt)
# Out:
# 'no'
